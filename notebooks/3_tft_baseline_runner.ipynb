# %% [markdown]
# # TFT Baseline (no sentiment) Runner
#
# This notebook mirrors the TimesFM notebook structure and calls the TFT pipeline via `models/tft_baseline.py`.

# %%
# Ensure project root is on sys.path for `import models`
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
# Import and reload TFT module
import importlib
from models import tft_baseline as tft_auto
importlib.reload(tft_auto)
# Out:
# <module 'models.tft_baseline' from '/Users/hwang-yejin/Desktop/Summer1/Proposal/code_cleaning/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/models/tft_baseline.py'>

# %%
# Run TFT pipeline (interactive prompts inside)
from models.tft_baseline import main as tft_main

tft_main()
# Out:
# 🚀 Starting Automated TFT Analysis...
# Seed set to 42 (default)
# ✓ pytorch_forecasting already installed
# Seed set to 42
# ✓ yfinance already installed
# ✓ All libraries imported successfully!
#
# === TFT Configuration ===
#
# ✓ Configuration set:
#   - Training period: start at 2025-02-01 for 96 data rows
#   - Prediction horizon: 5 days
#   - Max epochs: 20
#   - Batch size: 128
#   - Learning rate: 0.03
# Using data file: /Users/hwang-yejin/Desktop/Summer1/Proposal/code_cleaning/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/data/processed/TSLA_full_features.csv
#
# === Loading and Preparing Data ===
# ✓ Data loaded successfully from /Users/hwang-yejin/Desktop/Summer1/Proposal/code_cleaning/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/data/processed/TSLA_full_features.csv
#   - Shape: (483, 21)
#   - Date range: 2023-07-20 to 2025-06-23
#
# Data columns (normalized):
# ['date', 'open', 'high', 'low', 'close', 'volume', 'last_earnings_date', 'days_since_earning', 'month', 'day_of_week', 'quarter', 'year', 'is_month_end', 'is_month_start', 'rolling_volatility', 'return_1d', 'cumulative_return', 'time_idx', 'tsla_close', 'unique_id', 'sentiment']
# ✓ No missing values found
# ⚠️ Adjusting training rows from 96 to 92 due to dataset end
# ✓ Windowed data from 2025-02-01 covering 92 training rows + 5 prediction rows
#   - Effective training end date: 2025-06-13
#   - Filtered shape: (97, 21)
#
# First few rows:
#                    date        open        high         low       close  \
# 386 2025-02-03 05:00:00  386.679993  389.170013  374.359985  383.679993
# 387 2025-02-04 05:00:00  382.630005  394.000000  381.399994  392.209991
# 388 2025-02-05 05:00:00  387.510010  388.390015  375.529999  378.170013
# 389 2025-02-06 05:00:00  373.029999  375.399994  363.179993  374.320007
# 390 2025-02-07 05:00:00  370.190002  380.549988  360.339996  361.619995
#
#        volume         last_earnings_date  days_since_earning  month  \
# 386  93732100  2025-01-29 16:12:00-05:00                 4.0      2
# 387  57072200  2025-01-29 16:12:00-05:00                 5.0      2
# 388  57223300  2025-01-29 16:12:00-05:00                 6.0      2
# 389  77918200  2025-01-29 16:12:00-05:00                 7.0      2
# 390  70298300  2025-01-29 16:12:00-05:00                 8.0      2
#
#      day_of_week  ...  year  is_month_end  is_month_start  rolling_volatility  \
# 386            0  ...  2025             0               0           12.138329
# 387            1  ...  2025             0               0           10.020263
# 388            2  ...  2025             0               0           10.590211
# 389            3  ...  2025             0               0           10.971099
# 390            4  ...  2025             0               0           13.454038
#
#      return_1d  cumulative_return  time_idx  tsla_close  unique_id sentiment
# 386  -0.051705         240.904091         0  383.679993       TSLA         0
# 387   0.022232         246.259887         1  392.209991       TSLA         0
# 388  -0.035797         237.444499         2  378.170013       TSLA         0
# 389  -0.010181         235.027166         3  374.320007       TSLA         0
# 390  -0.033928         227.053112         4  361.619995       TSLA         0
#
# [5 rows x 21 columns]
#
# === Creating TFT Dataset ===
#   - Total data points: 97
#   - Encoder length: 92 days
#   - Prediction length: 5 days
#   - Minimum required length: 97 days
#   - Training cutoff: time_idx 91
#   - Small window detected (97 rows). Using full window without mask.
#   - Known features: ['time_idx', 'month', 'day_of_week', 'quarter', 'year', 'is_month_end', 'is_month_start', 'days_since_earning']
#   - Unknown features: ['close', 'volume', 'rolling_volatility']
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✓ Training dataset created with 1 samples
#
# === Creating Model and DataLoader ===
# ✓ DataLoader created with batch size 128
# ✓ TFT model created with 26,608 parameters
#   - Learning rate: 0.03
#   - Hidden size: 16
#   - Attention heads: 1
#
# === Training TFT Model ===
# ✓ Trainer configured with 20 max epochs
#   - Early stopping enabled
#   - Learning rate monitoring enabled
#   - Model checkpointing enabled
#
# Starting model training...
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | TorchMetricWrapper              | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 1      | train
# 3  | prescalers                         | ModuleDict                      | 176    | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 48     | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 7.4 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 5.1 K  | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 17     | train
# ------------------------------------------------------------------------------------------------
# 26.6 K    Trainable params
# 0         Non-trainable params
# 26.6 K    Total params
# 0.106     Total estimated model params size (MB)
# 424       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# Metric train_loss improved. New best score: 3362.382
# Metric train_loss improved by 2859.712 >= min_delta = 0.0001. New best score: 502.670
# Metric train_loss improved by 138.591 >= min_delta = 0.0001. New best score: 364.079
# Metric train_loss improved by 178.859 >= min_delta = 0.0001. New best score: 185.220
# Metric train_loss improved by 20.311 >= min_delta = 0.0001. New best score: 164.909
# Metric train_loss improved by 34.093 >= min_delta = 0.0001. New best score: 130.817
# Metric train_loss improved by 9.949 >= min_delta = 0.0001. New best score: 120.867
# Metric train_loss improved by 2.544 >= min_delta = 0.0001. New best score: 118.323
# Metric train_loss improved by 4.660 >= min_delta = 0.0001. New best score: 113.663
# Metric train_loss improved by 19.497 >= min_delta = 0.0001. New best score: 94.166
# Metric train_loss improved by 11.662 >= min_delta = 0.0001. New best score: 82.504
# Metric train_loss improved by 18.795 >= min_delta = 0.0001. New best score: 63.708
# `Trainer.fit` stopped: `max_epochs=20` reached.
# ✅ Training completed!
#
# === Loading Best Model and Creating Validation Dataset ===
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✓ Best model loaded from: /Users/hwang-yejin/Desktop/Summer1/Proposal/code_cleaning/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/notebooks/checkpoints/tft-epoch=16-train_loss=63.7081.ckpt
# ✓ Validation dataset created with 1 samples
#
# === Making Predictions ===
# ✓ Predictions made successfully
#   - Prediction shape: torch.Size([1, 5])
#   - Actuals shape: torch.Size([1, 5])
#
# === Performance Evaluation ===
#
# 📊 Model Performance Metrics:
#                            Metric    Value
# 0       MAE (Mean Absolute Error)   7.7285
# 1        MSE (Mean Squared Error)  82.4690
# 2  RMSE (Root Mean Squared Error)   9.0812
#
# === Creating Visualizations ===
#
# === Creating Standalone Training + Prediction Plot ===
# Plot saved to /Users/hwang-yejin/Desktop/Summer1/Proposal/code_cleaning/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/results/TSLA_TFT_baseline_forecast.png
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# ✓ Standalone plot created successfully!
#
# === Model Interpretation ===
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ⚠️ Model interpretation failed: 'TemporalFusionTransformer' object has no attribute 'plot_attention'
# This is optional and doesn't affect the main predictions.
#
# === Saving Results ===
#
# ## Update Results Matrix
# ✓ Loaded existing results matrix
#
# Current matrix:
#                MAE         MSE       RMSE
# ARIMA    16.274952  343.830831  18.542676
# timesfm  16.721159  324.364743  18.010129
# chronos  10.581822  192.236770  13.864948
#
# Adding TFT model results...
#
# Updated matrix:
#                     MAE         MSE       RMSE
# ARIMA         16.274952  343.830831  18.542676
# timesfm       16.721159  324.364743  18.010129
# chronos       10.581822  192.236770  13.864948
# TFT_reddit_N   7.728546   82.469048   9.081247
#
# TFT analysis complete.
# 📊 Model trained on 92 days of data
# 🔮 Predictions made for 5 days ahead
# 📈 Best RMSE: 9.0812
