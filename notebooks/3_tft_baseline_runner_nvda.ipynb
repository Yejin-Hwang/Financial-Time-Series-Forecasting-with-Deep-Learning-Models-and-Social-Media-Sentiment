# %% [markdown]
# # TFT Baseline (no sentiment) Runner
#
# This notebook mirrors the TimesFM notebook structure and calls the TFT pipeline via `models/tft_baseline.py`.

# %%
# Ensure project root is on sys.path for `import models`
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from models.tft_baseline_nvda import main as tft_baseline_nvda_main

# %%
# Run TFT pipeline (interactive prompts inside)
import time

start_time = time.time()
tft_baseline_nvda_main()
end_time = time.time()

execution_time = end_time - start_time
print(f"Execution time: {end_time - start_time:.2f} seconds")
# Out:
# 🚀 Starting Automated TFT Analysis...
# Seed set to 42 (default)
# ✓ pytorch_forecasting already installed
# Seed set to 42
# ✓ yfinance already installed
# ✓ All libraries imported successfully!
#
# === TFT Configuration ===
#
# ✓ Configuration set:
#   - Training start: 2025-02-01
#   - Training days: 96
#   - Prediction days: 5
#   - Max epochs: 20
#   - Batch size: 128
#   - Learning rate: 0.03
# Using data file: /Users/hwang-yejin/Desktop/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/data/processed/NVDA_full_features.csv
#
# === Loading and Preparing Data ===
# ✓ Data loaded successfully from /Users/hwang-yejin/Desktop/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/data/processed/NVDA_full_features.csv
#   - Shape: (395, 21)
#   - Date range: 2023-11-22 to 2025-06-23
#
# Data columns (normalized):
# ['date', 'open', 'high', 'low', 'close', 'volume', 'last_earnings_date', 'days_since_earning', 'month', 'day_of_week', 'quarter', 'year', 'is_month_end', 'is_month_start', 'rolling_volatility', 'return_1d', 'cumulative_return', 'time_idx', 'nvda_close', 'unique_id', 'sentiment']
# ✓ No missing values found
# ✓ Using date_anchor approach with user-specified start date
#   - Training start: 2025-02-01
#   - Training days: 96
#   - Prediction days: 5
# ✓ Using 96 training days + 5 prediction days from 2025-02-01
#   - Total data range: 2025-02-03 05:00:00 to 2025-06-23 04:00:00
#   - Total data points: 97
#
# First few rows:
#                    date        open        high         low       close  \
# 298 2025-02-03 05:00:00  114.731479  118.550862  112.991762  116.641174
# 299 2025-02-04 05:00:00  116.941122  121.180436  116.681162  118.630852
# 300 2025-02-05 05:00:00  121.740348  124.979823  120.740510  124.809853
# 301 2025-02-06 05:00:00  127.399419  128.749207  125.189777  128.659210
# 302 2025-02-07 05:00:00  129.199136  130.348944  124.979816  129.819031
#
#         volume         last_earnings_date  days_since_earning  month  \
# 298  371235700  2024-11-20 16:20:00-05:00                74.0      2
# 299  256550000  2024-11-20 16:20:00-05:00                75.0      2
# 300  262230800  2024-11-20 16:20:00-05:00                76.0      2
# 301  251483600  2024-11-20 16:20:00-05:00                77.0      2
# 302  228186300  2024-11-20 16:20:00-05:00                78.0      2
#
#      day_of_week  ...  year  is_month_end  is_month_start  rolling_volatility  \
# 298            0  ...  2025             0               0           12.172650
# 299            1  ...  2025             0               0           12.207816
# 300            2  ...  2025             0               0           10.403651
# 301            3  ...  2025             0               0            7.588988
# 302            4  ...  2025             0               0            4.808389
#
#      return_1d  cumulative_return  time_idx  nvda_close  unique_id sentiment
# 298  -0.028400        3101.409485         0  116.641174       NVDA         0
# 299   0.017058        3154.313655         1  118.630852       NVDA         0
# 300   0.052086        3318.609084         2  124.809853       NVDA         0
# 301   0.030842        3420.960885         3  128.659210       NVDA         0
# 302   0.009015        3451.799724         4  129.819031       NVDA         0
#
# [5 rows x 21 columns]
#
# === Creating TFT Dataset ===
#   - Total data points: 97
#   - Encoder length: 96 days
#   - Prediction length: 5 days
#   - Minimum required length: 101 days
# ❌ Error: Insufficient data!
#   - Available: 97 days
#   - Required: 101 days
#   - Shortage: 4 days
#
# 🔄 Auto-adjusting to use available data...
#   - Adjusted encoder length: 92 days
#   - Adjusted encoder length to 91 to use all available data
#   - Using all 97 data points for training
#   - Small window detected (97 rows). Using full window without mask.
#   - Known features: ['time_idx', 'month', 'day_of_week', 'quarter', 'year', 'is_month_end', 'is_month_start', 'days_since_earning', 'rolling_volatility']
#   - Unknown features: ['close', 'volume']
# ✓ Training dataset created with 2 samples
#
# === Creating Model and DataLoader ===
# ✓ DataLoader created with batch size 128
# ✓ TFT model created with 27,332 parameters
#   - Learning rate: 0.03
#   - Hidden size: 16
#   - Attention heads: 1
#
# === Training TFT Model ===
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✓ Trainer configured with 20 max epochs
#   - Early stopping enabled
#   - Learning rate monitoring enabled
#   - Model checkpointing enabled
#
# Starting model training...
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | TorchMetricWrapper              | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 1      | train
# 3  | prescalers                         | ModuleDict                      | 176    | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 48     | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 7.4 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 5.9 K  | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 17     | train
# ------------------------------------------------------------------------------------------------
# 27.3 K    Trainable params
# 0         Non-trainable params
# 27.3 K    Total params
# 0.109     Total estimated model params size (MB)
# 438       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# Metric train_loss improved. New best score: 606.525
# Metric train_loss improved by 586.945 >= min_delta = 0.0001. New best score: 19.579
# Metric train_loss improved by 4.952 >= min_delta = 0.0001. New best score: 14.628
# Metric train_loss improved by 8.153 >= min_delta = 0.0001. New best score: 6.474
# Metric train_loss improved by 4.829 >= min_delta = 0.0001. New best score: 1.646
# Metric train_loss improved by 0.752 >= min_delta = 0.0001. New best score: 0.894
# Monitored metric train_loss did not improve in the last 5 records. Best score: 0.894. Signaling Trainer to stop.
# ✅ Training completed!
#
# === Loading Best Model and Creating Validation Dataset ===
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# ✓ Best model loaded from: /Users/hwang-yejin/Desktop/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/notebooks/checkpoints/tft-epoch=08-train_loss=0.8938-v2.ckpt
# ✓ Validation dataset created with 1 samples
#
# === Making Predictions ===
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✓ Predictions made successfully
#   - Prediction shape: torch.Size([1, 5])
#   - Actuals shape: torch.Size([1, 5])
#
# === Performance Evaluation ===
#
# 📊 Model Performance Metrics:
#                                   Metric   Value
# 0              MAE (Mean Absolute Error)  1.8987
# 1               MSE (Mean Squared Error)  3.9212
# 2         RMSE (Root Mean Squared Error)  1.9802
# 3  MAPE (Mean Absolute Percentage Error)  1.3159
#
# === Creating Visualizations ===
# DEBUG: Visualization df shape: (97, 21)
# DEBUG: Visualization df date range: 2025-02-03 05:00:00 to 2025-06-23 04:00:00
# DEBUG: Visualization df time_idx range: 0 to 96
#
# === Creating Standalone Training + Prediction Plot ===
# Plot saved to /Users/hwang-yejin/Desktop/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/results/NVDA_TFT_baseline_forecast.png
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ✓ Standalone plot created successfully!
#
# === Model Interpretation ===
# ⚠️ Model interpretation failed: 'TemporalFusionTransformer' object has no attribute 'plot_attention'
# This is optional and doesn't affect the main predictions.
#
# === Saving Results ===
#
# ## Update Results Matrix
# ✓ Loaded existing results matrix
#
# Current matrix:
#                    MAE        MSE      RMSE      MAPE
# ARIMA         4.970876  43.679190  6.609023  3.261838
# TimesFM       6.822006  68.188286  8.257620  4.501396
# chronos       7.102666  70.669240  8.406500  4.592989
# TFT_baseline  2.541815   8.370005  2.893096  2.340080
#
# Adding TFT model results...
#
# Updated matrix:
#                    MAE        MSE      RMSE      MAPE
# ARIMA         4.970876  43.679190  6.609023  3.261838
# TimesFM       6.822006  68.188286  8.257620  4.501396
# chronos       7.102666  70.669240  8.406500  4.592989
# TFT_baseline  1.898660   3.921175  1.980196  1.315865
#
# TFT analysis complete.
# 📊 Model trained on 92 days of data
# 🔮 Predictions made for 5 days ahead
# 📈 Best RMSE: 1.9802
# Execution time: 133.08 seconds

# %%
# Display training loss plot saved by the script
import os
from IPython.display import display, Image

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
plot_path = os.path.join(project_root, 'results', 'NVDA_TFT_baseline_train_loss.png')

if os.path.exists(plot_path):
  display(Image(filename=plot_path))
else:
  print('Training loss plot not found at:', plot_path)
  print('Run the pipeline cell above first, then re-run this cell.')
# Out:
# Training loss plot not found at: /Users/hwang-yejin/Desktop/Financial Time Series Forecasting with Deep Learning Models and Social Media Sentiment/results/NVDA_TFT_baseline_train_loss.png
# Run the pipeline cell above first, then re-run this cell.

# %%
# Save/append execution time to a unified matrix under results/
import os, pickle, pathlib
import pandas as pd

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
results_dir = os.path.join(PROJECT_ROOT, 'results')
os.makedirs(results_dir, exist_ok=True)

ticker = 'NVDA'
model_name = 'TFT_baseline'
pkl_path = pathlib.Path(results_dir) / f'{ticker}_execution_time.pkl'
csv_path = pathlib.Path(results_dir) / f'{ticker}_execution_time_matrix.csv'

# Ensure execution_time exists
try:
  execution_time
except NameError:
  execution_time = None

if execution_time is None:
  print('⚠️ execution_time is not defined; skipped saving.')
else:
  # Load existing
  try:
    if pkl_path.exists():
      with open(pkl_path, 'rb') as f:
        exec_df = pickle.load(f)
    else:
      exec_df = pd.DataFrame(columns=['Execution Time'])
  except Exception:
    exec_df = pd.DataFrame(columns=['Execution Time'])

  # Append/update row
  exec_df.loc[model_name] = [execution_time]

  # Save
  with open(pkl_path, 'wb') as f:
    pickle.dump(exec_df, f)
  exec_df.to_csv(csv_path, index=True)

  print('\nTotal Execution Time Matrix:')
  print(exec_df)
# Out:
# Total Execution Time Matrix:
#                            Execution Time
# ARIMA                           14.227170
# TimesFM                         30.039453
# Chronos                         12.905276
# TFT_baseline                   133.075988
# TFT_with_Reddit_Sentiment       60.289374
